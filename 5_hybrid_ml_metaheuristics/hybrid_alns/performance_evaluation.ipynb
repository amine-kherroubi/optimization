# %% [markdown]
# # Hybrid ALNS Performance Evaluation
#
# ---
#
# ## I. Purpose
#
# This notebook defines a **controlled benchmark procedure** to evaluate the Hybrid ALNS solver, which utilizes an offline repair model to guide neighborhood reconstruction.
#
# The objective is to analyze solution quality and computational efficiency.

# %% [markdown]
# ## II. Experimental Preconditions and Reproducibility Controls
#
# Required artifacts and assumptions:
# - trained model file `models/repair_model.pkl`,
# - benchmark instance directory (`../instances` by default),
# - fixed random seed and defined iteration/time budgets.

# %% [markdown]
# ## III. Hybrid Run (ALNS with Offline Repair Model)
#
# This run executes the ALNS solver with learned repair ranking via `model_path=models/repair_model.pkl`.

# %%
# !python ../../utilities/benchmarking.py \
    --solver 5_hybrid_ml_metaheuristics/hybrid_alns/solver.py \
    --dataset falkenauer-t \
    --method-args max_iterations=2000,model_path=models/repair_model.pkl \
    --csv-out hybrid_alns_results.csv
# Out:
# Starting Benchmark: Falkenauer T
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# Instance          │ Items │ Capacity │ LB │ Bins │ Gap │ Time (s)   │ Method               │ State
# ──────────────────────────────────────────────────────────────────────────────────────────────────
# Falkenauer_t60_00 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 1.9820     │ <default>            │ Done
# Falkenauer_t60_01 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.2024     │ <default>            │ Done
# Falkenauer_t60_02 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.2540     │ <default>            │ Done
# Falkenauer_t60_03 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.2633     │ <default>            │ Done
# Falkenauer_t60_04 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.2139     │ <default>            │ Done
# Falkenauer_t60_05 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.2120     │ <default>            │ Done
# Falkenauer_t60_06 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.2115     │ <default>            │ Done
# Falkenauer_t60_07 │ 60    │ 1000     │ 20 │ 21   │ 1   │ 0.4587     │ <default>            │ Done
# Falkenauer_t60_08 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.1905     │ <default>            │ Done
# Falkenauer_t60_09 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.1809     │ <default>            │ Done
# Falkenauer_t60_10 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.1778     │ <default>            │ Done
# Falkenauer_t60_11 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.2268     │ <default>            │ Done
# Falkenauer_t60_12 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.1791     │ <default>            │ Done
# Falkenauer_t60_13 │ 60    │ 1000     │ 20 │ 21   │ 1   │ 0.4840     │ <default>            │ Done
# Falkenauer_t60_14 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.3199     │ <default>            │ Done
# Falkenauer_t60_15 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.2595     │ <default>            │ Done
# Falkenauer_t60_16 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.3674     │ <default>            │ Done
# Falkenauer_t60_17 │ 60    │ 1000     │ 20 │ 23   │ 3   │ 0.3395     │ <default>            │ Done
# Falkenauer_t60_18 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.2652     │ <default>            │ Done
# Falkenauer_t60_19 │ 60    │ 1000     │ 20 │ 22   │ 2   │ 0.3533     │ <default>            │ Done
# ──────────────────────────────────────────────────────────────────────────────────────────────────
#
# ══════════════════════════════════════════════════════════════════════════════════════════════════
#                                        BENCHMARK STATISTICS
# ══════════════════════════════════════════════════════════════════════════════════════════════════
# Instances processed      : 20
# Average time (completed) : 0.3571 s
# Average bins (completed) : 22.35
# Total elapsed time       : 7.1416 s
# ══════════════════════════════════════════════════════════════════════════════════════════════════
